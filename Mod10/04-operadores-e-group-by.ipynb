# %% [markdown]
# # Data Science Academy
#
# ## Capítulo 10 - Manipulação de Dados com Pandas

# %% [markdown]
# ### Usando Operadores Lógicos para Manipular Dados com Pandas
#
# Os operadores lógicos são excelentes para filtrar dataframes e tetornar exatamente os dados que precisamos para nosso trabalho.

# %% [markdown]
# Primeiro usaremos o operador lógico __AND__ para chegar duas condições. Serão retornados os registros quando as duas condições forem verdadeiras

# %%
import pandas as pd

# %%
df = pd.read_csv('dataset.csv')

# %%
# Filtrando as vendas que ocorreram para o segmendo de Home Office e na região South
df[(df.Segmento == 'Home Office') & (df.Regiao == 'South')].head()
# Out:
#           ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais Regiao  \
# 182  CA-2014-158274  2014-11-19   RM-19675  Home Office  United States  South
# 183  CA-2014-158274  2014-11-19   RM-19675  Home Office  United States  South
# 184  CA-2014-158274  2014-11-19   RM-19675  Home Office  United States  South
# 231  US-2017-100930  2017-04-07   CS-12400  Home Office  United States  South
# 232  US-2017-100930  2017-04-07   CS-12400  Home Office  United States  South
#
#           ID_Produto   Categoria  \
# 182  TEC-PH-10003273  Technology
# 183  TEC-PH-10004896  Technology
# 184  TEC-AC-10002345  Technology
# 231  FUR-TA-10001705   Furniture
# 232  FUR-TA-10003473   Furniture
#
#                                          Nome_Produto  Valor_Venda  Quantidade
# 182                                      AT&T TR1909W     503.9600         4.0
# 183                        Nokia Lumia 521 (T-Mobile)     149.9500         5.0
# 184                 HP Standard 104 key PS/2 Keyboard      29.0000         2.0
# 231  Bush Advantage Collection Round Conference Table     233.8600         2.0
# 232        Bretford Rectangular Conference Table Tops     620.6145         3.0

# %%
# Filtrando as vendas que ocorreram para o Segmento Home Office ou Região South
df[(df.Segmento == 'Home Office') | (df.Regiao == 'South')].tail()
# Out:
#            ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 9979  US-2016-103674  2016-12-06   AP-10720  Home Office  United States
# 9980  US-2015-151435  2015-09-06   SW-20455     Consumer  United States
# 9987  CA-2017-163629  2017-11-17   RA-19885    Corporate  United States
# 9988  CA-2017-163629  2017-11-17   RA-19885    Corporate  United States
# 9989  CA-2014-110422  2014-01-21   TB-21400     Consumer  United States
#
#      Regiao       ID_Produto        Categoria  \
# 9979   West  OFF-BI-10002026  Office Supplies
# 9980  South  FUR-TA-10001029        Furniture
# 9987  South  TEC-AC-10001539       Technology
# 9988  South  TEC-PH-10004006       Technology
# 9989  South  FUR-FU-10001889        Furniture
#
#                                            Nome_Produto  Valor_Venda  \
# 9979                  Ibico Recycled Linen-Style Covers      437.472
# 9980                         KI Adjustable-Height Table       85.980
# 9987  Logitech G430 Surround Sound Gaming Headset wi...       79.990
# 9988                    Panasonic KX - TS880B Telephone      206.100
# 9989                             Ultra Door Pull Handle       25.248
#
#       Quantidade
# 9979        14.0
# 9980         1.0
# 9987         1.0
# 9988         5.0
# 9989         3.0

# %% [markdown]
# `Observação:` O método `head()` retorna os 5 primeiros registros. O método `tail()` retorna os 5 últimos registros do dataset. O método `sample()` usado abaixo retorna 5 amostras aleatórias da tabela.

# %%
# Filtrando as vendas que não ocorreram para o segmento Home Office e nem na região South
df[(df.Segmento != 'Home Office') & (df.Regiao != 'South')].sample(5)
# Out:
#            ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 871   CA-2015-131128  2015-10-19   TB-21520   Consumer  United States
# 8819  CA-2015-142930  2015-11-28   EB-14170   Consumer  United States
# 6793  CA-2015-145394  2015-11-16   MC-17605  Corporate  United States
# 2894  CA-2017-139913  2017-10-23   JC-16105  Corporate  United States
# 331   US-2016-150147  2016-04-25   JL-15850   Consumer  United States
#
#        Regiao       ID_Produto        Categoria  \
# 871      East  OFF-PA-10003591  Office Supplies
# 8819  Central  OFF-PA-10003395  Office Supplies
# 6793  Central  OFF-ST-10000344  Office Supplies
# 2894     East  FUR-FU-10000771        Furniture
# 331      East  TEC-PH-10004614       Technology
#
#                                          Nome_Produto  Valor_Venda  Quantidade
# 871             Southworth 100% Cotton The Best Paper       34.440         3.0
# 8819                                       Xerox 1941      335.520         4.0
# 6793  Neat Ideas Personal Hanging Folder Files, Black       21.488         2.0
# 2894          Eldon 200 Class Desk Accessories, Smoke       69.080        11.0
# 331                                 AT&T 841000 Phone       82.800         2.0

# %% [markdown]
# ### Agrupamento de Dados em DataFrames com Group By
# A função Pandas `Group By`é uma função versátil e fácil de usar que ajuda a obter uma visão geral dos dados. Isso torna mais fácil explorar o conjunto de dados e revelar os relacionamentos entre as variáveis.

# %% [markdown]
# Na instrução abaixo, primeiro filtramos os dados extraindo 3 colunas: ['Segmento', 'Regiao', 'Valor_Venda']. Na sequência, agrupamos por duas colunas ['Segmento', 'Regiao']. __E então calculamos a média para a coluna que ficou do groupby, nesse caso a coluna Valor_Venda.__ Esse comportamento também é observado em SQL.

# %%
df[['Segmento', 'Regiao', 'Valor_Venda']].groupby(['Segmento', 'Regiao']).mean()
# Out:
#                      Valor_Venda
# Segmento    Regiao
# Consumer    Central   207.946728
#             East      238.875539
#             South     233.390180
#             West      217.033955
# Corporate   Central   234.763466
#             East      228.516929
#             South     238.992025
#             West      235.265911
# Home Office Central   208.248046
#             East      253.911805
#             South     272.996329
#             West      239.442692

# %% [markdown]
# #### Agregação Múltipla com o Group By

# %% [markdown]
# Na instrução abaixo, primeiro filtramos os dados extraindo 3 colunas ['Segmento', 'Regiao', 'Valor_Venda']. Na sequência, agrupamos por duas colunas ['Segmento', 'Regiao']. E então agregamos os dados calculando a média, desvio padrão e contagem de elementos para a coluna que ficou fora do group by, neste caso a coluna Valor_Venda.
#
# - A função `agg()`recebe como argumento uma lista de funções para agregação.

# %%
df[['Segmento', 'Regiao', 'Valor_Venda']].groupby(['Segmento', 'Regiao']).agg(['mean', 'std', 'count'])
# Out:
#                     Valor_Venda
#                            mean          std count
# Segmento    Regiao
# Consumer    Central  207.946728   587.906523  1212
#             East     238.875539   633.371169  1469
#             South    233.390180   559.346824   838
#             West     217.033955   551.997547  1672
# Corporate   Central  234.763466   818.947521   673
#             East     228.516929   530.001654   877
#             South    238.992025   586.176947   510
#             West     235.265911   471.288764   960
# Home Office Central  208.248046   371.009180   438
#             East     253.911805   722.777318   502
#             South    272.996329  1404.798466   272
#             West     239.442692   529.242737   571
